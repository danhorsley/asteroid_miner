# %%
from poliastro.bodies import Earth, Sun
from poliastro.twobody import Orbit
from poliastro.maneuver import Maneuver
from poliastro.plotting import OrbitPlotter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from poliastro.bodies import Earth, Sun
# ----> 2 from poliastro.twobody import Orbit
#       3 from poliastro.maneuver import Maneuver
#       4 from poliastro.plotting import OrbitPlotter
#
# File ~/Desktop/AM/.venv/lib/python3.13/site-packages/poliastro/twobody/__init__.py:3
#       1 # coding: utf-8
# ----> 3 from poliastro.twobody.orbit import Orbit
#
# File ~/Desktop/AM/.venv/lib/python3.13/site-packages/poliastro/twobody/orbit.py:12
#      10 from poliastro.constants import J2000
#      11 from poliastro.ephem import get_body_ephem
# ---> 12 from poliastro.twobody.propagation import propagate
#      14 import poliastro.twobody.rv
#      15 import poliastro.twobody.classical
#
# File ~/Desktop/AM/.venv/lib/python3.13/site-packages/poliastro/twobody/propagation.py:7
#       2 """Propagation algorithms.
#       3
#       4 """
#       5 import numpy as np
# ----> 7 from scipy.integrate import ode
#       9 from astropy import units as u
#      11 from numba import njit as jit
#
# ModuleNotFoundError: No module named 'scipy'
